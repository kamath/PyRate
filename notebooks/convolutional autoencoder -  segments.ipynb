# %%
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
import random


import keras
from matplotlib import pyplot as plt
# %matplotlib inline
from keras import backend as K
from keras.layers import Input,Conv2D,MaxPooling2D,UpSampling2D, Conv2DTranspose
from keras.layers import Input,Conv1D,MaxPool1D,UpSampling1D
from keras.models import Model
from keras.optimizers import RMSprop
from keras import callbacks

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
df = pd.read_json(os.path.join('..', 'input', 'sample_analysis.json'))
df
# Out:
#                                                  track  \
# 0    {'album': {'album_type': 'album', 'artists': [...
# 1    {'album': {'album_type': 'album', 'artists': [...
# 2    {'album': {'album_type': 'album', 'artists': [...
# 3    {'album': {'album_type': 'album', 'artists': [...
# 4    {'album': {'album_type': 'album', 'artists': [...
# ..                                                 ...
# 505  {'album': {'album_type': 'single', 'artists': ...
# 506  {'album': {'album_type': 'album', 'artists': [...
# 507  {'album': {'album_type': 'album', 'artists': [...
# 508  {'album': {'album_type': 'album', 'artists': [...
# 509  {'album': {'album_type': 'album', 'artists': [...
#
#                                               features  \
# 0    {'danceability': 0.559, 'energy': 0.33, 'key':...
# 1    {'danceability': 0.874, 'energy': 0.6920000000...
# 2    {'danceability': 0.759, 'energy': 0.548, 'key'...
# 3    {'danceability': 0.861, 'energy': 0.603, 'key'...
# 4    {'danceability': 0.777, 'energy': 0.782, 'key'...
# ..                                                 ...
# 505  {'danceability': 0.554, 'energy': 0.669, 'key'...
# 506  {'danceability': 0.766, 'energy': 0.709, 'key'...
# 507  {'danceability': 0.673, 'energy': 0.886, 'key'...
# 508  {'danceability': 0.592, 'energy': 0.767, 'key'...
# 509  {'danceability': 0.745, 'energy': 0.356, 'key'...
#
#                                               analysis
# 0    {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 1    {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 2    {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 3    {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 4    {'meta': {'analyzer_version': '4.0.0', 'platfo...
# ..                                                 ...
# 505  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 506  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 507  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 508  {'meta': {'analyzer_version': '4.0.0', 'platfo...
# 509  {'meta': {'analyzer_version': '4.0.0', 'platfo...
#
# [510 rows x 3 columns]

# %%
def segment_to_vector(segment):
    return list(map(abs, [segment['duration'], segment['loudness_start'], segment['loudness_max_time'], segment['loudness_max']]\
        + segment['pitches'] + segment['timbre']))

arrs = [list(map(segment_to_vector, sample['segments'])) for sample in df['analysis']]
# del df

# %%
# arrs = list(map(np.array, arrs))
dim2_length = len(arrs[0][0])
to_pad = 800 #max(map(len, arrs))

for i in tqdm(range(len(arrs))):
    if len(arrs[i]) >= to_pad:
        arrs[i] = arrs[i][:to_pad]
    else:
        arrs[i] += [np.zeros(dim2_length) for _ in range(to_pad - len(arrs[i]))]
# Out:
# 100%|██████████| 510/510 [00:00<00:00, 7175.62it/s]

# %%
arrs = np.array(arrs) #* 1000
# arrs = arrs.reshape([*list(arrs.shape), 1])
arrs = arrs / arrs.max(axis=0)
arrs.shape
# Out:
# (510, 800, 28)

# %%
from sklearn.model_selection import train_test_split

random_state=23
test_size=0.2

X_train, X_test = train_test_split(arrs,
                                   test_size=test_size,
                                   random_state=random_state)

# %%
batch_size = 8
epochs = 10
input_image = Input(shape=arrs.shape[1:])

# %%
from datetime import datetime
dt = datetime.today() 
currentDate = ''.join([str(dt.year), str(dt.month), str(dt.day)])

bestModelName = ''.join([currentDate,'AutoEncoder','.h5'])

# %%
#encoder
#input = 428 x 600 x 3
conv1 = Conv1D(28, (5), activation='relu', padding='same', name='conv1')(input_image) #428 x 600 x 32
pool1 = MaxPool1D(pool_size=(4))(conv1) #14 x 14 x 32
conv2 = Conv1D(64, (5), activation='relu', padding='same', name='conv2')(pool1) #214 x 300 x 64
pool2 = MaxPool1D(pool_size=(4))(conv2) #7 x 7 x 64
conv3 = Conv1D(128, (5), activation='relu', padding='same', name='conv3')(pool2) #107 x 150 x 128 

#decoder
conv4 = Conv1D(128, (5), activation='relu', padding='same', name='conv4')(conv3) #107 x 150 x 128 
up1 = UpSampling1D((4))(conv4) # 14 x 14 x 128
conv5 = Conv1D(64, (5), activation='relu', padding='same', name='conv5')(up1) #214 x 300 x 64
up2 = UpSampling1D((4))(conv5) # 28 x 28 x 64
decoded = Conv1D(28, (5), activation='sigmoid', padding='same', name='conv6')(up2) #428 x 600 x 3

autoencoder = Model(input_image, decoded)

early_stopping = callbacks.EarlyStopping(monitor='val_loss',patience=3, verbose=True)

bestModelFilepath = os.path.join('.','models',bestModelName)
checkpoint = callbacks.ModelCheckpoint(bestModelFilepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

loss = keras.losses.mse
optimizer = keras.optimizers.Adam()
history = keras.callbacks.History()

autoencoder.compile(loss=loss, optimizer = optimizer)
autoencoder.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 800, 28)           0
# _________________________________________________________________
# conv1 (Conv1D)               (None, 800, 28)           3948
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 200, 28)           0
# _________________________________________________________________
# conv2 (Conv1D)               (None, 200, 64)           9024
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 50, 64)            0
# _________________________________________________________________
# conv3 (Conv1D)               (None, 50, 128)           41088
# _________________________________________________________________
# conv4 (Conv1D)               (None, 50, 128)           82048
# _________________________________________________________________
# up_sampling1d_17 (UpSampling (None, 200, 128)          0
# _________________________________________________________________
# conv5 (Conv1D)               (None, 200, 64)           41024
# _________________________________________________________________
# up_sampling1d_18 (UpSampling (None, 800, 64)           0
# _________________________________________________________________
# conv6 (Conv1D)               (None, 800, 28)           8988
# =================================================================
# Total params: 186,120
# Trainable params: 186,120
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.fit(X_train, X_train, batch_size=batch_size,epochs=100, \
                                    callbacks=[early_stopping, checkpoint, history], verbose=True,validation_split=0.2)
# Out:
# Train on 326 samples, validate on 82 samples
# Epoch 1/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0661 - val_loss: 0.0542
#
# Epoch 00001: val_loss improved from inf to 0.05424, saving model to ./models/2020217AutoEncoder.h5
# Epoch 2/100
# 326/326 [==============================] - 2s 6ms/step - loss: 0.0527 - val_loss: 0.0521
#
# Epoch 00002: val_loss improved from 0.05424 to 0.05207, saving model to ./models/2020217AutoEncoder.h5
# Epoch 3/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0518 - val_loss: 0.0513
#
# Epoch 00003: val_loss improved from 0.05207 to 0.05127, saving model to ./models/2020217AutoEncoder.h5
# Epoch 4/100
# 326/326 [==============================] - 2s 6ms/step - loss: 0.0501 - val_loss: 0.0498
#
# Epoch 00004: val_loss improved from 0.05127 to 0.04983, saving model to ./models/2020217AutoEncoder.h5
# Epoch 5/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0488 - val_loss: 0.0485
#
# Epoch 00005: val_loss improved from 0.04983 to 0.04851, saving model to ./models/2020217AutoEncoder.h5
# Epoch 6/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0477 - val_loss: 0.0481
#
# Epoch 00006: val_loss improved from 0.04851 to 0.04807, saving model to ./models/2020217AutoEncoder.h5
# Epoch 7/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0468 - val_loss: 0.0470
#
# Epoch 00007: val_loss improved from 0.04807 to 0.04704, saving model to ./models/2020217AutoEncoder.h5
# Epoch 8/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0460 - val_loss: 0.0469
#
# Epoch 00008: val_loss improved from 0.04704 to 0.04689, saving model to ./models/2020217AutoEncoder.h5
# Epoch 9/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0456 - val_loss: 0.0460
#
# Epoch 00009: val_loss improved from 0.04689 to 0.04599, saving model to ./models/2020217AutoEncoder.h5
# Epoch 10/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0450 - val_loss: 0.0455
#
# Epoch 00010: val_loss improved from 0.04599 to 0.04555, saving model to ./models/2020217AutoEncoder.h5
# Epoch 11/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0445 - val_loss: 0.0452
#
# Epoch 00011: val_loss improved from 0.04555 to 0.04525, saving model to ./models/2020217AutoEncoder.h5
# Epoch 12/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0440 - val_loss: 0.0449
#
# Epoch 00012: val_loss improved from 0.04525 to 0.04485, saving model to ./models/2020217AutoEncoder.h5
# Epoch 13/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0437 - val_loss: 0.0445
#
# Epoch 00013: val_loss improved from 0.04485 to 0.04450, saving model to ./models/2020217AutoEncoder.h5
# Epoch 14/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0434 - val_loss: 0.0441
#
# Epoch 00014: val_loss improved from 0.04450 to 0.04409, saving model to ./models/2020217AutoEncoder.h5
# Epoch 15/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0430 - val_loss: 0.0437
#
# Epoch 00015: val_loss improved from 0.04409 to 0.04370, saving model to ./models/2020217AutoEncoder.h5
# Epoch 16/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0426 - val_loss: 0.0434
#
# Epoch 00016: val_loss improved from 0.04370 to 0.04337, saving model to ./models/2020217AutoEncoder.h5
# Epoch 17/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0423 - val_loss: 0.0433
#
# Epoch 00017: val_loss improved from 0.04337 to 0.04328, saving model to ./models/2020217AutoEncoder.h5
# Epoch 18/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0420 - val_loss: 0.0432
#
# Epoch 00018: val_loss improved from 0.04328 to 0.04323, saving model to ./models/2020217AutoEncoder.h5
# Epoch 19/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0419 - val_loss: 0.0429
#
# Epoch 00019: val_loss improved from 0.04323 to 0.04293, saving model to ./models/2020217AutoEncoder.h5
# Epoch 20/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0416 - val_loss: 0.0426
#
# Epoch 00020: val_loss improved from 0.04293 to 0.04256, saving model to ./models/2020217AutoEncoder.h5
# Epoch 21/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0414 - val_loss: 0.0423
#
# Epoch 00021: val_loss improved from 0.04256 to 0.04227, saving model to ./models/2020217AutoEncoder.h5
# Epoch 22/100
# 326/326 [==============================] - 2s 8ms/step - loss: 0.0413 - val_loss: 0.0424
#
# Epoch 00022: val_loss did not improve from 0.04227
# Epoch 23/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0411 - val_loss: 0.0422
#
# Epoch 00023: val_loss improved from 0.04227 to 0.04217, saving model to ./models/2020217AutoEncoder.h5
# Epoch 24/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0409 - val_loss: 0.0421
#
# Epoch 00024: val_loss improved from 0.04217 to 0.04210, saving model to ./models/2020217AutoEncoder.h5
# Epoch 25/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0407 - val_loss: 0.0420
#
# Epoch 00025: val_loss improved from 0.04210 to 0.04203, saving model to ./models/2020217AutoEncoder.h5
# Epoch 26/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0406 - val_loss: 0.0418
#
# Epoch 00026: val_loss improved from 0.04203 to 0.04183, saving model to ./models/2020217AutoEncoder.h5
# Epoch 27/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0406 - val_loss: 0.0417
#
# Epoch 00027: val_loss improved from 0.04183 to 0.04171, saving model to ./models/2020217AutoEncoder.h5
# Epoch 28/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0404 - val_loss: 0.0416
#
# Epoch 00028: val_loss improved from 0.04171 to 0.04163, saving model to ./models/2020217AutoEncoder.h5
# Epoch 29/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0402 - val_loss: 0.0414
#
# Epoch 00029: val_loss improved from 0.04163 to 0.04139, saving model to ./models/2020217AutoEncoder.h5
# Epoch 30/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0401 - val_loss: 0.0415
#
# Epoch 00030: val_loss did not improve from 0.04139
# Epoch 31/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0401 - val_loss: 0.0414
#
# Epoch 00031: val_loss did not improve from 0.04139
# Epoch 32/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0400 - val_loss: 0.0413
#
# Epoch 00032: val_loss improved from 0.04139 to 0.04132, saving model to ./models/2020217AutoEncoder.h5
# Epoch 33/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0398 - val_loss: 0.0412
#
# Epoch 00033: val_loss improved from 0.04132 to 0.04116, saving model to ./models/2020217AutoEncoder.h5
# Epoch 34/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0396 - val_loss: 0.0409
#
# Epoch 00034: val_loss improved from 0.04116 to 0.04094, saving model to ./models/2020217AutoEncoder.h5
# Epoch 35/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0396 - val_loss: 0.0410
#
# Epoch 00035: val_loss did not improve from 0.04094
# Epoch 36/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0396 - val_loss: 0.0409
#
# Epoch 00036: val_loss improved from 0.04094 to 0.04086, saving model to ./models/2020217AutoEncoder.h5
# Epoch 37/100
# 326/326 [==============================] - 2s 7ms/step - loss: 0.0394 - val_loss: 0.0407
#
# Epoch 00037: val_loss improved from 0.04086 to 0.04074, saving model to ./models/2020217AutoEncoder.h5
# Epoch 38/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0393 - val_loss: 0.0406
#
# Epoch 00038: val_loss improved from 0.04074 to 0.04063, saving model to ./models/2020217AutoEncoder.h5
# Epoch 39/100
# 326/326 [==============================] - 4s 11ms/step - loss: 0.0393 - val_loss: 0.0407
#
# Epoch 00039: val_loss did not improve from 0.04063
# Epoch 40/100
# 326/326 [==============================] - 4s 14ms/step - loss: 0.0392 - val_loss: 0.0406
#
# Epoch 00040: val_loss improved from 0.04063 to 0.04062, saving model to ./models/2020217AutoEncoder.h5
# Epoch 41/100
# 326/326 [==============================] - 3s 10ms/step - loss: 0.0392 - val_loss: 0.0405
#
# Epoch 00041: val_loss improved from 0.04062 to 0.04050, saving model to ./models/2020217AutoEncoder.h5
# Epoch 42/100
# 326/326 [==============================] - 3s 10ms/step - loss: 0.0391 - val_loss: 0.0407
#
# Epoch 00042: val_loss did not improve from 0.04050
# Epoch 43/100
# 326/326 [==============================] - 3s 10ms/step - loss: 0.0390 - val_loss: 0.0404
#
# Epoch 00043: val_loss improved from 0.04050 to 0.04041, saving model to ./models/2020217AutoEncoder.h5
# Epoch 44/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0389 - val_loss: 0.0405
#
# Epoch 00044: val_loss did not improve from 0.04041
# Epoch 45/100
# 326/326 [==============================] - 3s 10ms/step - loss: 0.0389 - val_loss: 0.0402
#
# Epoch 00045: val_loss improved from 0.04041 to 0.04022, saving model to ./models/2020217AutoEncoder.h5
# Epoch 46/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0388 - val_loss: 0.0402
#
# Epoch 00046: val_loss did not improve from 0.04022
# Epoch 47/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0387 - val_loss: 0.0402
#
# Epoch 00047: val_loss improved from 0.04022 to 0.04020, saving model to ./models/2020217AutoEncoder.h5
# Epoch 48/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0387 - val_loss: 0.0402
#
# Epoch 00048: val_loss improved from 0.04020 to 0.04016, saving model to ./models/2020217AutoEncoder.h5
# Epoch 49/100
# 326/326 [==============================] - 3s 8ms/step - loss: 0.0387 - val_loss: 0.0403
#
# Epoch 00049: val_loss did not improve from 0.04016
# Epoch 50/100
# 326/326 [==============================] - 3s 9ms/step - loss: 0.0387 - val_loss: 0.0402
#
# Epoch 00050: val_loss did not improve from 0.04016
# Epoch 51/100
# 326/326 [==============================] - 4s 11ms/step - loss: 0.0386 - val_loss: 0.0402
#
# Epoch 00051: val_loss did not improve from 0.04016
# Epoch 00051: early stopping

# %%
for i,j in enumerate(autoencoder.layers):
    print(i,j, j.name)
# Out:
# 0 <keras.engine.input_layer.InputLayer object at 0x71106ac90> input_12
# 1 <keras.layers.convolutional.Conv1D object at 0x777631d10> conv1
# 2 <keras.layers.pooling.MaxPooling1D object at 0x777632210> max_pooling1d_18
# 3 <keras.layers.convolutional.Conv1D object at 0x777917490> conv2
# 4 <keras.layers.pooling.MaxPooling1D object at 0x77aa6e810> max_pooling1d_19
# 5 <keras.layers.convolutional.Conv1D object at 0x77efffa90> conv3
# 6 <keras.layers.convolutional.Conv1D object at 0x77e3fa050> conv4
# 7 <keras.layers.convolutional.UpSampling1D object at 0x7838ed410> up_sampling1d_17
# 8 <keras.layers.convolutional.Conv1D object at 0x78b80b910> conv5
# 9 <keras.layers.convolutional.UpSampling1D object at 0x7870e0f50> up_sampling1d_18
# 10 <keras.layers.convolutional.Conv1D object at 0x1bc1593210> conv6

# %%
get_Z_output = K.function([autoencoder.get_layer(name='conv1').input],[autoencoder.get_layer(name='conv3').output])
get_recreated_image = K.function([autoencoder.get_layer(name='conv4').input],[autoencoder.get_layer(name='conv6').output])

# %%
def add_shoes(shoelist):
    assert len(shoelist) > 0
    
    newShoeArray = get_Z_output([shoelist[0].reshape(1,arrs.shape[1], arrs.shape[2])])[0]
    for shoe in shoelist[1:]:
        newShoeArray += get_Z_output([shoe.reshape(1,arrs.shape[1], arrs.shape[2])])[0]
    
    return get_recreated_image([newShoeArray])[0]

add_shoes(X_train[0:2])
# Out:
# array([[[3.1625301e-02, 9.8970526e-01, 2.9714108e-03, ...,
#          2.6577502e-02, 4.3489784e-02, 4.3766886e-02],
#         [3.3635199e-02, 9.6257293e-01, 6.1200857e-03, ...,
#          7.5248480e-02, 5.5717111e-02, 9.5482290e-02],
#         [3.3257008e-02, 6.0541940e-01, 1.7037094e-02, ...,
#          3.9539605e-02, 4.9884021e-02, 7.6803774e-02],
#         ...,
#         [4.1127205e-06, 8.9406967e-08, 1.7791986e-05, ...,
#          1.9502640e-04, 5.8650970e-05, 3.4904480e-04],
#         [1.9580126e-05, 2.6822090e-07, 4.2408705e-05, ...,
#          3.0294061e-04, 1.4275312e-04, 8.1193447e-04],
#         [1.9049644e-04, 2.3245811e-06, 8.3684921e-05, ...,
#          6.6310167e-04, 7.3546171e-04, 2.0207465e-03]]], dtype=float32)

# %%
zVectorDF = pd.DataFrame(columns=['name', 'artists', 'zVector'])

for i, shoe in enumerate(df['track']):
    name = shoe['name']
    artists = '; '.join([a['name'] for a in shoe['artists']])
    zVector = get_Z_output(arrs[i:i+1])[0]
    zVectorDF.loc[i] = (name, artists, zVector.flatten().reshape(-1,1))
    print(f'Stored: {name}, shoe {i} complete')
# Out:
# Stored: Someone Like You, shoe 0 complete
# Stored: Treasure, shoe 1 complete
# Stored: Señorita, shoe 2 complete
# Stored: ZEZE, shoe 3 complete
# Stored: Me Niego (feat. Ozuna & Wisin), shoe 4 complete
# Stored: Feel So Close - Radio Edit, shoe 5 complete
# Stored: Goodbyes (feat. Young Thug), shoe 6 complete
# Stored: Sunflower - Spider-Man: Into the Spider-Verse, shoe 7 complete
# Stored: GDFR (feat. Sage the Gemini & Lookas), shoe 8 complete
# Stored: I Feel It Coming, shoe 9 complete
# Stored: I'm Yours, shoe 10 complete
# Stored: Smells Like Teen Spirit, shoe 11 complete
# Stored: Échame La Culpa, shoe 12 complete
# Stored: Titanium (feat. Sia), shoe 13 complete
# Stored: Havana, shoe 14 complete
# Stored: Boy With Luv (feat. Halsey), shoe 15 complete
# Stored: Trap Queen, shoe 16 complete
# Stored: Thinking out Loud, shoe 17 complete
# Stored: Old Town Road (feat. Billy Ray Cyrus) - Remix, shoe 18 complete
# Stored: DNA., shoe 19 complete
# Stored: Issues, shoe 20 complete
# Stored: Body Like A Back Road, shoe 21 complete
# Stored: Nonstop, shoe 22 complete
# Stored: bad guy, shoe 23 complete
# Stored: Bounce Back, shoe 24 complete
# Stored: The Next Episode, shoe 25 complete
# Stored: In My Blood, shoe 26 complete
# Stored: Back In Black, shoe 27 complete
# Stored: Stay With Me, shoe 28 complete
# Stored: River (feat. Ed Sheeran), shoe 29 complete
# Stored: No Role Modelz, shoe 30 complete
# Stored: Rather Be (feat. Jess Glynne), shoe 31 complete
# Stored: BUTTERFLY EFFECT, shoe 32 complete
# Stored: Lose Yourself - From "8 Mile" Soundtrack, shoe 33 complete
# Stored: I Fall Apart, shoe 34 complete
# Stored: Ransom, shoe 35 complete
# Stored: Low Life, shoe 36 complete
# Stored: Mercy, shoe 37 complete
# Stored: Firestone (feat. Conrad Sewell), shoe 38 complete
# Stored: Cold Water, shoe 39 complete
# Stored: Stronger, shoe 40 complete
# Stored: Young Dumb & Broke, shoe 41 complete
# Stored: Youngblood, shoe 42 complete
# Stored: Thrift Shop (feat. Wanz), shoe 43 complete
# Stored: Old Town Road, shoe 44 complete
# Stored: Eastside (with Halsey & Khalid), shoe 45 complete
# Stored: Blurred Lines, shoe 46 complete
# Stored: Moves Like Jagger - Studio Recording From The Voice Performance, shoe 47 complete
# Stored: It Wasn't Me, shoe 48 complete
# Stored: I Won't Give Up, shoe 49 complete
# Stored: Passionfruit, shoe 50 complete
# Stored: Bad Romance, shoe 51 complete
# Stored: Chandelier, shoe 52 complete
# Stored: X, shoe 53 complete
# Stored: Sucker For Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors), shoe 54 complete
# Stored: What Do You Mean?, shoe 55 complete
# Stored: Sucker, shoe 56 complete
# Stored: Snow (Hey Oh), shoe 57 complete
# Stored: Ho Hey, shoe 58 complete
# Stored: Weak, shoe 59 complete
# Stored: Drip Too Hard (Lil Baby & Gunna), shoe 60 complete
# Stored: Lean On (feat. MØ & DJ Snake), shoe 61 complete
# Stored: Yes Indeed, shoe 62 complete
# Stored: lovely (with Khalid), shoe 63 complete
# Stored: Rap God, shoe 64 complete
# Stored: All of Me, shoe 65 complete
# Stored: Slippery (feat. Gucci Mane), shoe 66 complete
# Stored: Numb / Encore, shoe 67 complete
# Stored: when the party's over, shoe 68 complete
# Stored: iSpy (feat. Lil Yachty), shoe 69 complete
# Stored: thank u, next, shoe 70 complete
# Stored: Prayer in C - Robin Schulz Radio Edit, shoe 71 complete
# Stored: Love The Way You Lie, shoe 72 complete
# Stored: Faded, shoe 73 complete
# Stored: Lush Life, shoe 74 complete
# Stored: Radioactive, shoe 75 complete
# Stored: Talk (feat. Disclosure), shoe 76 complete
# Stored: Latch, shoe 77 complete
# Stored: Déjala Que Vuelva (feat. Manuel Turizo), shoe 78 complete
# Stored: Hey Brother, shoe 79 complete
# Stored: How Far I'll Go - Alessia Cara Version, shoe 80 complete
# Stored: Rockabye (feat. Sean Paul & Anne-Marie), shoe 81 complete
# Stored: On Top Of The World, shoe 82 complete
# Stored: 1-800-273-8255, shoe 83 complete
# Stored: Worth It, shoe 84 complete
# Stored: Every Breath You Take, shoe 85 complete
# Stored: Ain't Nobody (Loves Me Better), shoe 86 complete
# Stored: Home, shoe 87 complete
# Stored: China, shoe 88 complete
# Stored: Halo, shoe 89 complete
# Stored: Say You Won't Let Go, shoe 90 complete
# Stored: Glorious (feat. Skylar Grey), shoe 91 complete
# Stored: There's Nothing Holdin' Me Back, shoe 92 complete
# Stored: Don't Call Me Up, shoe 93 complete
# Stored: Girls Like You (feat. Cardi B), shoe 94 complete
# Stored: Hello, shoe 95 complete
# Stored: Stay (feat. Maty Noyes), shoe 96 complete
# Stored: Felices los 4, shoe 97 complete
# Stored: The A Team, shoe 98 complete
# Stored: Bad Things (with Camila Cabello), shoe 99 complete
# Stored: 'Till I Collapse, shoe 100 complete
# Stored: Mr. Brightside, shoe 101 complete
# Stored: We Can't Stop, shoe 102 complete
# Stored: Somebody That I Used To Know, shoe 103 complete
# Stored: Here, shoe 104 complete
# Stored: Mirrors, shoe 105 complete
# Stored: Hey Ya!, shoe 106 complete
# Stored: Iris, shoe 107 complete
# Stored: When I Was Your Man, shoe 108 complete
# Stored: Wasted, shoe 109 complete
# Stored: Te Boté - Remix, shoe 110 complete
# Stored: Like I'm Gonna Lose You (feat. John Legend), shoe 111 complete
# Stored: God is a woman, shoe 112 complete
# Stored: Roar, shoe 113 complete
# Stored: My Way, shoe 114 complete
# Stored: Promises (with Sam Smith), shoe 115 complete
# Stored: Better, shoe 116 complete
# Stored: Sex, shoe 117 complete
# Stored: XO Tour Llif3, shoe 118 complete
# Stored: Dusk Till Dawn - Radio Edit, shoe 119 complete
# Stored: Cake By The Ocean, shoe 120 complete
# Stored: Callaita, shoe 121 complete
# Stored: Panini, shoe 122 complete
# Stored: Danza Kuduro, shoe 123 complete
# Stored: Body, shoe 124 complete
# Stored: Gold, shoe 125 complete
# Stored: Bad and Boujee (feat. Lil Uzi Vert), shoe 126 complete
# Stored: Mercy, shoe 127 complete
# Stored: Hall of Fame, shoe 128 complete
# Stored: Middle, shoe 129 complete
# Stored: Don't Stop Me Now - 2011 Mix, shoe 130 complete
# Stored: 24K Magic, shoe 131 complete
# Stored: Where Are Ü Now (with Justin Bieber), shoe 132 complete
# Stored: No Money, shoe 133 complete
# Stored: Finesse - Remix; feat. Cardi B, shoe 134 complete
# Stored: Taste (feat. Offset), shoe 135 complete
# Stored: Hands To Myself, shoe 136 complete
# Stored: Dark Horse, shoe 137 complete
# Stored: Fancy, shoe 138 complete
# Stored: Gold Digger, shoe 139 complete
# Stored: Come As You Are, shoe 140 complete
# Stored: This Girl (Kungs Vs. Cookin' On 3 Burners), shoe 141 complete
# Stored: Water Under the Bridge, shoe 142 complete
# Stored: Friends (with BloodPop®), shoe 143 complete
# Stored: El Perdón, shoe 144 complete
# Stored: Break Free, shoe 145 complete
# Stored: Call Out My Name, shoe 146 complete
# Stored: Send My Love (To Your New Lover), shoe 147 complete
# Stored: Rise, shoe 148 complete
# Stored: Despacito (Featuring Daddy Yankee), shoe 149 complete
# Stored: Sex on Fire, shoe 150 complete
# Stored: Intro, shoe 151 complete
# Stored: More Than You Know, shoe 152 complete
# Stored: Galway Girl, shoe 153 complete
# Stored: Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit, shoe 154 complete
# Stored: Love Lies (with Normani), shoe 155 complete
# Stored: Waves - Robin Schulz Radio Edit, shoe 156 complete
# Stored: Stressed Out, shoe 157 complete
# Stored: Can't Hold Us - feat. Ray Dalton, shoe 158 complete
# Stored: 7/11, shoe 159 complete
# Stored: Sugar, shoe 160 complete
# Stored: Starboy, shoe 161 complete
# Stored: Scared to Be Lonely, shoe 162 complete
# Stored: Lay It All on Me, shoe 163 complete
# Stored: Circles, shoe 164 complete
# Stored: Bank Account, shoe 165 complete
# Stored: In the Name of Love, shoe 166 complete
# Stored: I Like Me Better, shoe 167 complete
# Stored: She Will Be Loved - Radio Mix, shoe 168 complete
# Stored: Midnight City, shoe 169 complete
# Stored: Ain't No Mountain High Enough, shoe 170 complete
# Stored: Go Flex, shoe 171 complete
# Stored: 2002, shoe 172 complete
# Stored: Castle on the Hill, shoe 173 complete
# Stored: Back to You (feat. Bebe Rexha & Digital Farm Animals), shoe 174 complete
# Stored: I Don't Care (with Justin Bieber), shoe 175 complete
# Stored: Fast Car, shoe 176 complete
# Stored: Bang Bang, shoe 177 complete
# Stored: Silence, shoe 178 complete
# Stored: MIDDLE CHILD, shoe 179 complete
# Stored: Money In The Grave (Drake ft. Rick Ross), shoe 180 complete
# Stored: Dangerous Woman, shoe 181 complete
# Stored: Better Now, shoe 182 complete
# Stored: Sweet Dreams (Are Made of This) - Remastered, shoe 183 complete
# Stored: Are You With Me - Radio Edit, shoe 184 complete
# Stored: How to Save a Life, shoe 185 complete
# Stored: Strip That Down, shoe 186 complete
# Stored: Candy Paint, shoe 187 complete
# Stored: Young, Wild & Free (feat. Bruno Mars), shoe 188 complete
# Stored: FEFE, shoe 189 complete
# Stored: Budapest, shoe 190 complete
# Stored: All We Know, shoe 191 complete
# Stored: Whatever It Takes, shoe 192 complete
# Stored: Happier, shoe 193 complete
# Stored: Solo (feat. Demi Lovato), shoe 194 complete
# Stored: rockstar, shoe 195 complete
# Stored: Soltera - Remix, shoe 196 complete
# Stored: Good For You, shoe 197 complete
# Stored: Hymn for the Weekend, shoe 198 complete
# Stored: Pompeii, shoe 199 complete
# Stored: Locked out of Heaven, shoe 200 complete
# Stored: 7 Years, shoe 201 complete
# Stored: Under Control (feat. Hurts), shoe 202 complete
# Stored: What Lovers Do (feat. SZA), shoe 203 complete
# Stored: Africa, shoe 204 complete
# Stored: Psycho (feat. Ty Dolla $ign), shoe 205 complete
# Stored: Last Christmas, shoe 206 complete
# Stored: Believer, shoe 207 complete
# Stored: Stole the Show, shoe 208 complete
# Stored: Viva La Vida, shoe 209 complete
# Stored: Treat You Better, shoe 210 complete
# Stored: Can't Feel My Face, shoe 211 complete
# Stored: Happier, shoe 212 complete
# Stored: PILLOWTALK, shoe 213 complete
# Stored: Bodak Yellow, shoe 214 complete
# Stored: Drunk in Love, shoe 215 complete
# Stored: Back To You - From 13 Reasons Why – Season 2 Soundtrack, shoe 216 complete
# Stored: Sugar (feat. Francesco Yates), shoe 217 complete
# Stored: CAN'T STOP THE FEELING! (Original Song from DreamWorks Animation's "TROLLS"), shoe 218 complete
# Stored: Look Alive (feat. Drake), shoe 219 complete
# Stored: The Ocean (feat. Shy Martin), shoe 220 complete
# Stored: It's Time, shoe 221 complete
# Stored: Mine, shoe 222 complete
# Stored: See You Again (feat. Charlie Puth), shoe 223 complete
# Stored: Call Me Maybe, shoe 224 complete
# Stored: Hymn for the Weekend - Seeb Remix, shoe 225 complete
# Stored: Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack), shoe 226 complete
# Stored: Happy - From "Despicable Me 2", shoe 227 complete
# Stored: i hate u, i love u (feat. olivia o'brien), shoe 228 complete
# Stored: All About That Bass, shoe 229 complete
# Stored: Demons, shoe 230 complete
# Stored: Don't Let Me Down (feat. Daya), shoe 231 complete
# Stored: Paint It, Black, shoe 232 complete
# Stored: Love Me Like You Do - From "Fifty Shades Of Grey", shoe 233 complete
# Stored: bury a friend, shoe 234 complete
# Stored: Sweet Child O' Mine, shoe 235 complete
# Stored: Dance Monkey, shoe 236 complete
# Stored: How Deep Is Your Love, shoe 237 complete
# Stored: White Iverson, shoe 238 complete
# Stored: Little Talks, shoe 239 complete
# Stored: I'm the One, shoe 240 complete
# Stored: Thunderstruck, shoe 241 complete
# Stored: Heathens, shoe 242 complete
# Stored: High Hopes, shoe 243 complete
# Stored: Chop Suey!, shoe 244 complete
# Stored: Never Forget You, shoe 245 complete
# Stored: Photograph, shoe 246 complete
# Stored: Mi Gente, shoe 247 complete
# Stored: I Miss You (feat. Julia Michaels), shoe 248 complete
# Stored: Symphony (feat. Zara Larsson), shoe 249 complete
# Stored: Needed Me, shoe 250 complete
# Stored: Time of Our Lives, shoe 251 complete
# Stored: Going Bad (feat. Drake), shoe 252 complete
# Stored: How Do You Sleep?, shoe 253 complete
# Stored: One Last Time, shoe 254 complete
# Stored: I Like It, shoe 255 complete
# Stored: Numb, shoe 256 complete
# Stored: Another One Bites The Dust - Remastered 2011, shoe 257 complete
# Stored: Want to Want Me, shoe 258 complete
# Stored: HIGHEST IN THE ROOM, shoe 259 complete
# Stored: Mask Off, shoe 260 complete
# Stored: Slow Hands, shoe 261 complete
# Stored: Work, shoe 262 complete
# Stored: Blame (feat. John Newman), shoe 263 complete
# Stored: Never Be Like You (feat. Kai), shoe 264 complete
# Stored: Criminal, shoe 265 complete
# Stored: I See Fire, shoe 266 complete
# Stored: Slide (feat. Frank Ocean & Migos), shoe 267 complete
# Stored: Ric Flair Drip (& Metro Boomin), shoe 268 complete
# Stored: Hotel California - 2013 Remaster, shoe 269 complete
# Stored: Rude, shoe 270 complete
# Stored: Do I Wanna Know?, shoe 271 complete
# Stored: changes, shoe 272 complete
# Stored: Creep, shoe 273 complete
# Stored: Sorry, shoe 274 complete
# Stored: Jocelyn Flores, shoe 275 complete
# Stored: Dancing With A Stranger (with Normani), shoe 276 complete
# Stored: Drag Me Down, shoe 277 complete
# Stored: No Promises (feat. Demi Lovato), shoe 278 complete
# Stored: Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix, shoe 279 complete
# Stored: One Kiss (with Dua Lipa), shoe 280 complete
# Stored: Stitches, shoe 281 complete
# Stored: Shape of You, shoe 282 complete
# Stored: Congratulations, shoe 283 complete
# Stored: Someone You Loved, shoe 284 complete
# Stored: We Are Young (feat. Janelle Monáe), shoe 285 complete
# Stored: God's Plan, shoe 286 complete
# Stored: Wolves, shoe 287 complete
# Stored: Whatever It Takes, shoe 288 complete
# Stored: I Wanna Dance with Somebody (Who Loves Me), shoe 289 complete
# Stored: Sweet but Psycho, shoe 290 complete
# Stored: The Nights, shoe 291 complete
# Stored: FourFiveSeconds, shoe 292 complete
# Stored: Otra vez (feat. J Balvin), shoe 293 complete
# Stored: Starving, shoe 294 complete
# Stored: Light It Up (feat. Nyla & Fuse ODG) [Remix], shoe 295 complete
# Stored: Vaina Loca, shoe 296 complete
# Stored: We Found Love (feat. Rihanna), shoe 297 complete
# Stored: Maps, shoe 298 complete
# Stored: One Dance, shoe 299 complete
# Stored: Earned It (Fifty Shades Of Grey) - From The "Fifty Shades Of Grey" Soundtrack, shoe 300 complete
# Stored: Pumped Up Kicks, shoe 301 complete
# Stored: Work from Home (feat. Ty Dolla $ign), shoe 302 complete
# Stored: Payphone, shoe 303 complete
# Stored: Capsize, shoe 304 complete
# Stored: I'm Not The Only One, shoe 305 complete
# Stored: Perfect Duet (Ed Sheeran & Beyoncé), shoe 306 complete
# Stored: Sin Pijama, shoe 307 complete
# Stored: Story of My Life, shoe 308 complete
# Stored: The Greatest, shoe 309 complete
# Stored: Solo Dance, shoe 310 complete
# Stored: Me, Myself & I, shoe 311 complete
# Stored: New Rules, shoe 312 complete
# Stored: Fake Love, shoe 313 complete
# Stored: Location, shoe 314 complete
# Stored: Just Give Me a Reason, shoe 315 complete
# Stored: Let Me Go (with Alesso, Florida Georgia Line & watt), shoe 316 complete
# Stored: Gucci Gang, shoe 317 complete
# Stored: Counting Stars, shoe 318 complete
# Stored: 7 rings, shoe 319 complete
# Stored: Waiting For Love, shoe 320 complete
# Stored: Don't Wanna Know, shoe 321 complete
# Stored: Party In The U.S.A., shoe 322 complete
# Stored: I Don’t Wanna Live Forever (Fifty Shades Darker), shoe 323 complete
# Stored: Closer, shoe 324 complete
# Stored: These Days (feat. Jess Glynne, Macklemore & Dan Caplen), shoe 325 complete
# Stored: Lucid Dreams, shoe 326 complete
# Stored: HUMBLE., shoe 327 complete
# Stored: I Don't Fuck With You, shoe 328 complete
# Stored: Fix You, shoe 329 complete
# Stored: Billie Jean, shoe 330 complete
# Stored: Bailando - Spanish Version, shoe 331 complete
# Stored: ROXANNE, shoe 332 complete
# Stored: Taki Taki (feat. Selena Gomez, Ozuna & Cardi B), shoe 333 complete
# Stored: A Thousand Years, shoe 334 complete
# Stored: Say Something, shoe 335 complete
# Stored: That's What I Like, shoe 336 complete
# Stored: Stolen Dance, shoe 337 complete
# Stored: Nice For What, shoe 338 complete
# Stored: No Problem (feat. Lil Wayne & 2 Chainz), shoe 339 complete
# Stored: Have You Ever Seen The Rain, shoe 340 complete
# Stored: Don't, shoe 341 complete
# Stored: break up with your girlfriend, i'm bored, shoe 342 complete
# Stored: Love On The Brain, shoe 343 complete
# Stored: Cheerleader - Felix Jaehn Remix Radio Edit, shoe 344 complete
# Stored: Too Good At Goodbyes, shoe 345 complete
# Stored: Moonlight, shoe 346 complete
# Stored: Under the Bridge, shoe 347 complete
# Stored: Truth Hurts, shoe 348 complete
# Stored: Take on Me, shoe 349 complete
# Stored: Beautiful People (feat. Khalid), shoe 350 complete
# Stored: Perfect, shoe 351 complete
# Stored: Take Me to Church, shoe 352 complete
# Stored: Summer, shoe 353 complete
# Stored: Timber (feat. Ke$ha), shoe 354 complete
# Stored: Royals, shoe 355 complete
# Stored: Some Nights, shoe 356 complete
# Stored: Sorry Not Sorry, shoe 357 complete
# Stored: Shallow, shoe 358 complete
# Stored: Uptown Funk, shoe 359 complete
# Stored: Sorry Not Sorry, shoe 360 complete
# Stored: Lose You To Love Me, shoe 361 complete
# Stored: Stay, shoe 362 complete
# Stored: Heroes (we could be), shoe 363 complete
# Stored: Feels (feat. Pharrell Williams, Katy Perry & Big Sean), shoe 364 complete
# Stored: Despacito - Remix, shoe 365 complete
# Stored: Pretty Girl - Cheat Codes X CADE Remix, shoe 366 complete
# Stored: When We Were Young, shoe 367 complete
# Stored: Something Just Like This, shoe 368 complete
# Stored: Unforgettable, shoe 369 complete
# Stored: Under Pressure - Remastered, shoe 370 complete
# Stored: IDGAF, shoe 371 complete
# Stored: Yeah! (feat. Lil Jon & Ludacris), shoe 372 complete
# Stored: Escápate Conmigo (feat. Ozuna), shoe 373 complete
# Stored: Chasing Cars, shoe 374 complete
# Stored: I Took A Pill In Ibiza - Seeb Remix, shoe 375 complete
# Stored: Bohemian Rhapsody - 2011 Mix, shoe 376 complete
# Stored: LOVE. FEAT. ZACARI., shoe 377 complete
# Stored: FRIENDS, shoe 378 complete
# Stored: Wannabe, shoe 379 complete
# Stored: Wow., shoe 380 complete
# Stored: Never Be the Same, shoe 381 complete
# Stored: Don't, shoe 382 complete
# Stored: Problem, shoe 383 complete
# Stored: Panda, shoe 384 complete
# Stored: Let It Go, shoe 385 complete
# Stored: Locked Away, shoe 386 complete
# Stored: Be Alright, shoe 387 complete
# Stored: Riptide, shoe 388 complete
# Stored: We Will Rock You - Remastered, shoe 389 complete
# Stored: Feel It Still, shoe 390 complete
# Stored: In My Mind, shoe 391 complete
# Stored: Jumpman, shoe 392 complete
# Stored: Eye of the Tiger, shoe 393 complete
# Stored: Bitch Better Have My Money, shoe 394 complete
# Stored: Wake Me Up, shoe 395 complete
# Stored: The Hills, shoe 396 complete
# Stored: Controlla, shoe 397 complete
# Stored: Seven Nation Army, shoe 398 complete
# Stored: Adan y Eva, shoe 399 complete
# Stored: Natural, shoe 400 complete
# Stored: Let Her Go, shoe 401 complete
# Stored: I Will Wait, shoe 402 complete
# Stored: Hold On, We're Going Home, shoe 403 complete
# Stored: Calma - Remix, shoe 404 complete
# Stored: Perfect Strangers, shoe 405 complete
# Stored: Free Fallin' - Live at the Nokia Theatre, Los Angeles, CA - December 2007, shoe 406 complete
# Stored: Paradise, shoe 407 complete
# Stored: Centuries, shoe 408 complete
# Stored: Con Calma, shoe 409 complete
# Stored: Me Rehúso, shoe 410 complete
# Stored: Stairway to Heaven - Remaster, shoe 411 complete
# Stored: Scars To Your Beautiful, shoe 412 complete
# Stored: Let Me Love You, shoe 413 complete
# Stored: Elastic Heart, shoe 414 complete
# Stored: Don't Stop Believin', shoe 415 complete
# Stored: Safe and Sound, shoe 416 complete
# Stored: Marvin Gaye, shoe 417 complete
# Stored: Too Good, shoe 418 complete
# Stored: Him & I (with Halsey), shoe 419 complete
# Stored: Call on Me - Ryan Riback Remix, shoe 420 complete
# Stored: Runaway (U & I), shoe 421 complete
# Stored: Sail, shoe 422 complete
# Stored: no tears left to cry, shoe 423 complete
# Stored: In the End, shoe 424 complete
# Stored: Ni**as In Paris, shoe 425 complete
# Stored: Sweater Weather, shoe 426 complete
# Stored: Can't Stop, shoe 427 complete
# Stored: Holy Grail, shoe 428 complete
# Stored: MIA (feat. Drake), shoe 429 complete
# Stored: Cheap Thrills, shoe 430 complete
# Stored: The Monster, shoe 431 complete
# Stored: Am I Wrong, shoe 432 complete
# Stored: Meant to Be (feat. Florida Georgia Line), shoe 433 complete
# Stored: Your Song, shoe 434 complete
# Stored: Mo Bamba, shoe 435 complete
# Stored: Rolling in the Deep, shoe 436 complete
# Stored: Wild Thoughts (feat. Rihanna & Bryson Tiller), shoe 437 complete
# Stored: Chantaje (feat. Maluma), shoe 438 complete
# Stored: Thunder, shoe 439 complete
# Stored: It Ain’t Me (with Selena Gomez), shoe 440 complete
# Stored: Outside, shoe 441 complete
# Stored: Classic, shoe 442 complete
# Stored: Hotline Bling, shoe 443 complete
# Stored: House Of The Rising Sun, shoe 444 complete
# Stored: Attention, shoe 445 complete
# Stored: In My Feelings, shoe 446 complete
# Stored: Walk It Talk It, shoe 447 complete
# Stored: Don't You Worry Child - Radio Edit, shoe 448 complete
# Stored: Side To Side, shoe 449 complete
# Stored: SICKO MODE, shoe 450 complete
# Stored: 679 (feat. Remy Boyz), shoe 451 complete
# Stored: Turn Down for What, shoe 452 complete
# Stored: All Girls Are The Same, shoe 453 complete
# Stored: The Middle, shoe 454 complete
# Stored: Everybody Dies In Their Nightmares, shoe 455 complete
# Stored: Fuck Love (feat. Trippie Redd), shoe 456 complete
# Stored: Just the Way You Are, shoe 457 complete
# Stored: Animals, shoe 458 complete
# Stored: Adventure of a Lifetime, shoe 459 complete
# Stored: Broccoli, shoe 460 complete
# Stored: All The Stars (with SZA), shoe 461 complete
# Stored: Highway to Hell, shoe 462 complete
# Stored: All Star, shoe 463 complete
# Stored: Welcome To The Jungle, shoe 464 complete
# Stored: Shotgun, shoe 465 complete
# Stored: Without Me, shoe 466 complete
# Stored: Mama, shoe 467 complete
# Stored: Levels - Radio Edit, shoe 468 complete
# Stored: Shut Up and Dance, shoe 469 complete
# Stored: Hips Don't Lie (feat. Wyclef Jean), shoe 470 complete
# Stored: Final Song, shoe 471 complete
# Stored: The Scientist, shoe 472 complete
# Stored: Into You, shoe 473 complete
# Stored: SAD!, shoe 474 complete
# Stored: F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar), shoe 475 complete
# Stored: Love Yourself, shoe 476 complete
# Stored: We Don't Talk Anymore, shoe 477 complete
# Stored: Yellow, shoe 478 complete
# Stored: Ride, shoe 479 complete
# Stored: Paris, shoe 480 complete
# Stored: Skinny Love, shoe 481 complete
# Stored: Please Don't Go, shoe 482 complete
# Stored: Sign of the Times, shoe 483 complete
# Stored: My House, shoe 484 complete
# Stored: Black Beatles, shoe 485 complete
# Stored: Make You Feel My Love, shoe 486 complete
# Stored: POWER, shoe 487 complete
# Stored: Wrecking Ball, shoe 488 complete
# Stored: Wonderwall - Remastered, shoe 489 complete
# Stored: Reggaetón Lento (Bailemos), shoe 490 complete
# Stored: Swalla (feat. Nicki Minaj & Ty Dolla $ign), shoe 491 complete
# Stored: Livin' On A Prayer, shoe 492 complete
# Stored: Without Me, shoe 493 complete
# Stored: All I Want for Christmas Is You, shoe 494 complete
# Stored: Roses, shoe 495 complete
# Stored: Sweet Home Alabama, shoe 496 complete
# Stored: This Is America, shoe 497 complete
# Stored: hot girl bummer, shoe 498 complete
# Stored: Fortunate Son, shoe 499 complete
# Stored: goosebumps, shoe 500 complete
# Stored: A Sky Full of Stars, shoe 501 complete
# Stored: This Is What You Came For, shoe 502 complete
# Stored: Let You Down, shoe 503 complete
# Stored: I Love It (feat. Charli XCX) - Original Version, shoe 504 complete
# Stored: Diamonds, shoe 505 complete
# Stored: Look What You Made Me Do, shoe 506 complete
# Stored: Hey, Soul Sister, shoe 507 complete
# Stored: Californication, shoe 508 complete
# Stored: Redbone, shoe 509 complete

# %%
from scipy import spatial

def create_cosine_similarity(shoe1, shoe2):
    result = 1 - spatial.distance.cosine(shoe1, shoe2)
    return result

# %%
def get_similar(ind):
    print('Songs most similar to', zVectorDF['name'][ind], 'by', zVectorDF['artists'][ind])
    ex = get_Z_output([arrs[ind:ind+1,:]])[0].flatten().reshape(-1,1)
    ll = []
    for i in zVectorDF.zVector:
        ll.append(create_cosine_similarity(i, ex))
    
    zVectorDF['similarity (cosine)'] = ll
    ind = pd.concat([
        zVectorDF.sort_values(by='similarity (cosine)', ascending=False).head()[['name', 'artists', 'similarity (cosine)']],
        zVectorDF.sort_values(by='similarity (cosine)', ascending=False).head()[['name', 'artists', 'similarity (cosine)']]])
    return ind

get_similar(10)
# Out:
# Songs most similar to I'm Yours by Jason Mraz
#                                                   name  \
# 10                                           I'm Yours
# 476                                      Love Yourself
# 364  Feels (feat. Pharrell Williams, Katy Perry & B...
# 262                                               Work
# 282                                       Shape of You
#
#                                                artists  similarity (cosine)
# 10                                          Jason Mraz             1.000000
# 476                                      Justin Bieber             0.833147
# 364  Calvin Harris; Pharrell Williams; Katy Perry; ...             0.825484
# 262                                     Rihanna; Drake             0.824314
# 282                                         Ed Sheeran             0.821271

# %%
# zVectorDF.loc[zVectorDF['artists'] == 'Travis Scott']
zVectorDF = zVectorDF.drop(['cosineScore'], axis=1)
